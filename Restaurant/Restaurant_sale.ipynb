# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Restaurant_sales.csv')

# %%
df.head()
# Out:
#    Order ID        Date             Product  Price  Quantity Purchase Type  \
# 0     10452  07-11-2022               Fries   3.49    573.07       Online
# 1     10453  07-11-2022           Beverages   2.95    745.76       Online
# 2     10454  07-11-2022       Sides & Other   4.99    200.40     In-store
# 3     10455  08-11-2022             Burgers  12.99    569.67     In-store
# 4     10456  08-11-2022  Chicken Sandwiches   9.95    201.01     In-store
#
#   Payment Method             Manager    City
# 0      Gift Card    Tom      Jackson  London
# 1      Gift Card         Pablo Perez  Madrid
# 2      Gift Card       Joao    Silva  Lisbon
# 3    Credit Card       Walter Muller  Berlin
# 4    Credit Card       Walter Muller  Berlin

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    int64
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    float64
#  4   Quantity        254 non-null    float64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 18.0+ KB

# %%
df.describe()
# Out:
#            Order ID       Price    Quantity
# count    254.000000  254.000000  254.000000
# mean   10584.133858    7.102323  460.611457
# std       75.889181    4.341855  214.888699
# min    10452.000000    2.950000  200.400000
# 25%    10520.250000    3.490000  201.010000
# 50%    10583.500000    4.990000  538.880000
# 75%    10649.750000    9.950000  677.440000
# max    10713.000000   29.050000  754.430000

# %%
df.shape
# Out:
# (254, 9)

# %%
df.tail()
# Out:
#      Order ID        Date             Product  Price  Quantity Purchase Type  \
# 249     10709  28-12-2022       Sides & Other   4.99    200.40   Drive-thru
# 250     10710  29-12-2022             Burgers  12.99    754.43   Drive-thru
# 251     10711  29-12-2022  Chicken Sandwiches   9.95    281.41   Drive-thru
# 252     10712  29-12-2022               Fries   3.49    630.37   Drive-thru
# 253     10713  29-12-2022           Beverages   2.95    677.97   Drive-thru
#
#     Payment Method        Manager    City
# 249      Gift Card  Walter Muller  Berlin
# 250      Gift Card  Walter Muller  Berlin
# 251      Gift Card  Walter Muller  Berlin
# 252      Gift Card  Walter Muller  Berlin
# 253      Gift Card  Walter Muller  Berlin

# %%
# df.columns = df.loc[0]
# df.drop(0) changes column Header

# %%
df.Manager.unique()
# Out:
# array(['Tom      Jackson', '       Pablo Perez', 'Joao    Silva',
#        'Walter Muller', 'Remy    Monet', 'Remy Monet',
#        '       Remy Monet', 'Remy     Monet', 'Pablo Perez',
#        'Pablo   Perez', 'Pablo  Perez', 'Pablo    Perez', 'Joao Silva',
#        'Tom Jackson'], dtype=object)

# %%
df.Manager.nunique()
# Out:
# 14

# %%
df.Manager.str.strip()
# Out:
# 0      Tom      Jackson
# 1           Pablo Perez
# 2         Joao    Silva
# 3         Walter Muller
# 4         Walter Muller
#              ...
# 249       Walter Muller
# 250       Walter Muller
# 251       Walter Muller
# 252       Walter Muller
# 253       Walter Muller
# Name: Manager, Length: 254, dtype: object

# %%
df.Manager.str.strip().str.replace(r'\s+',' ',regex=True)
# Out:
# 0        Tom Jackson
# 1        Pablo Perez
# 2         Joao Silva
# 3      Walter Muller
# 4      Walter Muller
#            ...
# 249    Walter Muller
# 250    Walter Muller
# 251    Walter Muller
# 252    Walter Muller
# 253    Walter Muller
# Name: Manager, Length: 254, dtype: object

# %%
df.Manager.unique()
# Out:
# array(['Tom      Jackson', '       Pablo Perez', 'Joao    Silva',
#        'Walter Muller', 'Remy    Monet', 'Remy Monet',
#        '       Remy Monet', 'Remy     Monet', 'Pablo Perez',
#        'Pablo   Perez', 'Pablo  Perez', 'Pablo    Perez', 'Joao Silva',
#        'Tom Jackson'], dtype=object)

# %%
df.Manager.unique()
# Out:
# array(['Tom      Jackson', '       Pablo Perez', 'Joao    Silva',
#        'Walter Muller', 'Remy    Monet', 'Remy Monet',
#        '       Remy Monet', 'Remy     Monet', 'Pablo Perez',
#        'Pablo   Perez', 'Pablo  Perez', 'Pablo    Perez', 'Joao Silva',
#        'Tom Jackson'], dtype=object)

# %%
df.Manager.nunique()
# Out:
# 14

# %%
round(df.describe(),)
# Out:
#        Order ID  Price  Quantity
# count     254.0  254.0     254.0
# mean    10584.0    7.0     461.0
# std        76.0    4.0     215.0
# min     10452.0    3.0     200.0
# 25%     10520.0    3.0     201.0
# 50%     10584.0    5.0     539.0
# 75%     10650.0   10.0     677.0
# max     10713.0   29.0     754.0

# %%
df['Order ID'].nunique()
# Out:
# 254

# %%
df['Order ID'].count()
# Out:
# np.int64(254)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    Order ID        Date             Product  Price  Quantity Purchase Type  \
# 0     10452  07-11-2022               Fries   3.49    573.07       Online
# 1     10453  07-11-2022           Beverages   2.95    745.76       Online
# 2     10454  07-11-2022       Sides & Other   4.99    200.40     In-store
# 3     10455  08-11-2022             Burgers  12.99    569.67     In-store
# 4     10456  08-11-2022  Chicken Sandwiches   9.95    201.01     In-store
#
#   Payment Method             Manager    City
# 0      Gift Card    Tom      Jackson  London
# 1      Gift Card         Pablo Perez  Madrid
# 2      Gift Card       Joao    Silva  Lisbon
# 3    Credit Card       Walter Muller  Berlin
# 4    Credit Card       Walter Muller  Berlin

# %%
df['Payment Method'].value_counts()
# Out:
# Payment Method
# Credit Card    120
# Cash            76
# Gift Card       58
# Name: count, dtype: int64

# %%
df['Payment Method'].value_counts(normalize=True)*100
# Out:
# Payment Method
# Credit Card    47.244094
# Cash           29.921260
# Gift Card      22.834646
# Name: proportion, dtype: float64

# %%
df['Payment Method'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Payment Method'>

# %%
df.head()
# Out:
#    Order ID        Date             Product  Price  Quantity Purchase Type  \
# 0     10452  07-11-2022               Fries   3.49    573.07       Online
# 1     10453  07-11-2022           Beverages   2.95    745.76       Online
# 2     10454  07-11-2022       Sides & Other   4.99    200.40     In-store
# 3     10455  08-11-2022             Burgers  12.99    569.67     In-store
# 4     10456  08-11-2022  Chicken Sandwiches   9.95    201.01     In-store
#
#   Payment Method             Manager    City
# 0      Gift Card    Tom      Jackson  London
# 1      Gift Card         Pablo Perez  Madrid
# 2      Gift Card       Joao    Silva  Lisbon
# 3    Credit Card       Walter Muller  Berlin
# 4    Credit Card       Walter Muller  Berlin

# %%
df.sort_values('Quantity', ascending = False).head(1)
# Out:
#      Order ID        Date  Product  Price  Quantity Purchase Type  \
# 250     10710  29-12-2022  Burgers  12.99    754.43   Drive-thru
#
#     Payment Method        Manager    City
# 250      Gift Card  Walter Muller  Berlin

# %%
df['TotalSales'] = df.Price * df.Quantity
df
# Out:
#      Order ID        Date             Product  Price  Quantity Purchase Type  \
# 0       10452  07-11-2022               Fries   3.49    573.07       Online
# 1       10453  07-11-2022           Beverages   2.95    745.76       Online
# 2       10454  07-11-2022       Sides & Other   4.99    200.40     In-store
# 3       10455  08-11-2022             Burgers  12.99    569.67     In-store
# 4       10456  08-11-2022  Chicken Sandwiches   9.95    201.01     In-store
# ..        ...         ...                 ...    ...       ...           ...
# 249     10709  28-12-2022       Sides & Other   4.99    200.40   Drive-thru
# 250     10710  29-12-2022             Burgers  12.99    754.43   Drive-thru
# 251     10711  29-12-2022  Chicken Sandwiches   9.95    281.41   Drive-thru
# 252     10712  29-12-2022               Fries   3.49    630.37   Drive-thru
# 253     10713  29-12-2022           Beverages   2.95    677.97   Drive-thru
#
# ...

# %%
df.sort_values('TotalSales', ascending = False).head(1)
# Out:
#     Order ID        Date Product  Price  Quantity Purchase Type  \
# 28     10482  13-11-2022   Fries   25.5    630.37     In-store
#
#    Payment Method     Manager    City  TotalSales
# 28    Credit Card  Joao Silva  Lisbon   16074.435

# %%
df.groupby('Product').Quantity.sum().sort_values(ascending=False)
# Out:
# Product
# Beverages             34983.14
# Fries                 32034.34
# Burgers               29022.31
# Chicken Sandwiches    11135.92
# Sides & Other          9819.60
# Name: Quantity, dtype: float64

# %%
df3 = df.groupby('Product')['TotalSales'].sum().sort_values(ascending=False)
df3
# Out:
# Product
# Burgers               376999.8069
# Fries                 125674.2903
# Chicken Sandwiches    114641.6950
# Beverages             103200.2630
# Sides & Other          48999.8040
# Name: TotalSales, dtype: float64

# %%
df.head()
# Out:
#    Order ID        Date             Product  Price  Quantity Purchase Type  \
# 0     10452  07-11-2022               Fries   3.49    573.07       Online
# 1     10453  07-11-2022           Beverages   2.95    745.76       Online
# 2     10454  07-11-2022       Sides & Other   4.99    200.40     In-store
# 3     10455  08-11-2022             Burgers  12.99    569.67     In-store
# 4     10456  08-11-2022  Chicken Sandwiches   9.95    201.01     In-store
#
#   Payment Method             Manager    City  TotalSales
# 0      Gift Card    Tom      Jackson  London   2000.0143
# 1      Gift Card         Pablo Perez  Madrid   2199.9920
# 2      Gift Card       Joao    Silva  Lisbon    999.9960
# 3    Credit Card       Walter Muller  Berlin   7400.0133
# 4    Credit Card       Walter Muller  Berlin   2000.0495

# %%
df.groupby('Date').TotalSales.sum().sort_values(ascending = True)
# Out:
# Date
# 07-11-2022     5200.0023
# 20-11-2022     8200.0466
# 04-12-2022     9000.1007
# 08-11-2022    12400.0731
# 10-11-2022    13200.0426
# 26-11-2022    13200.0638
# 27-11-2022    13399.9799
# 25-11-2022    13399.9799
# 28-11-2022    13400.0454
# 29-11-2022    13400.0454
# 01-12-2022    13400.1144
# 22-11-2022    13599.9918
# 24-11-2022    13600.0259
# 15-11-2022    13600.0305
# 16-11-2022    13600.0305
# 30-11-2022    13600.0914
# 23-11-2022    13800.0378
# 19-11-2022    14000.0194
# 12-11-2022    14000.0535
# 07-12-2022    14000.0535
# 02-12-2022    14000.0535
# 17-11-2022    14000.0535
# 03-12-2022    14000.0535
# 21-11-2022    14000.0838
# 06-12-2022    14000.1225
# 09-11-2022    14200.0386
# 05-12-2022    14200.0386
# 08-12-2022    14200.0995
# 11-11-2022    14400.0156
# 15-12-2022    14400.0945
# 18-11-2022    14400.1114
# 14-12-2022    14600.0106
# 10-12-2022    14600.0616
# 09-12-2022    14600.0616
# 13-12-2022    14600.0616
# 12-12-2022    14600.0616
# ...

# %%
df.Date.dtype
# Out:
# dtype('O')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    int64
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    float64
#  4   Quantity        254 non-null    float64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
#  9   TotalSales      254 non-null    float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 20.0+ KB

# %%
df.Date = pd.to_datetime(df.Date, format = '%d-%m-%Y')
df.head()
# df["Date"] = pd.to_datetime(df["Date"], format="%d-%m-%Y")
# Out:
#    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0     10452 2022-11-07               Fries   3.49    573.07       Online
# 1     10453 2022-11-07           Beverages   2.95    745.76       Online
# 2     10454 2022-11-07       Sides & Other   4.99    200.40     In-store
# 3     10455 2022-11-08             Burgers  12.99    569.67     In-store
# 4     10456 2022-11-08  Chicken Sandwiches   9.95    201.01     In-store
#
#   Payment Method             Manager    City  TotalSales
# 0      Gift Card    Tom      Jackson  London   2000.0143
# 1      Gift Card         Pablo Perez  Madrid   2199.9920
# 2      Gift Card       Joao    Silva  Lisbon    999.9960
# 3    Credit Card       Walter Muller  Berlin   7400.0133
# 4    Credit Card       Walter Muller  Berlin   2000.0495

# %%
df.Date.dtype
# Out:
# dtype('<M8[ns]')

# %%
df.groupby('Date').TotalSales.sum().sort_values(ascending = True)
# Out:
# Date
# 2022-11-07     5200.0023
# 2022-11-20     8200.0466
# 2022-12-04     9000.1007
# 2022-11-08    12400.0731
# 2022-11-10    13200.0426
# 2022-11-26    13200.0638
# 2022-11-25    13399.9799
# 2022-11-27    13399.9799
# 2022-11-28    13400.0454
# 2022-11-29    13400.0454
# 2022-12-01    13400.1144
# 2022-11-22    13599.9918
# 2022-11-24    13600.0259
# 2022-11-15    13600.0305
# 2022-11-16    13600.0305
# 2022-11-30    13600.0914
# 2022-11-23    13800.0378
# 2022-11-19    14000.0194
# 2022-12-02    14000.0535
# 2022-12-03    14000.0535
# 2022-12-07    14000.0535
# 2022-11-12    14000.0535
# 2022-11-17    14000.0535
# 2022-11-21    14000.0838
# 2022-12-06    14000.1225
# 2022-11-09    14200.0386
# 2022-12-05    14200.0386
# 2022-12-08    14200.0995
# 2022-11-11    14400.0156
# 2022-12-15    14400.0945
# 2022-11-18    14400.1114
# 2022-12-14    14600.0106
# 2022-12-13    14600.0616
# 2022-12-12    14600.0616
# 2022-12-09    14600.0616
# 2022-12-10    14600.0616
# ...

# %%
df.plot('Date','TotalSales', color = 'red', linewidth = 1, figsize = (14,7))
plt.title('Datewise Revenue')
plt.xlabel ('Date')
plt.ylabel('Revenue')
plt.show()

# %%
df.plot('Date','TotalSales', color = 'red', linewidth = 1, figsize = (14,7))
plt.title('Datewise Revenue')
plt.xlabel ('Date')
plt.ylabel('Revenue')
# Out:
# Text(0, 0.5, 'Revenue')

# %%
df.TotalSales.mean()
# Out:
# np.float64(3029.589996850394)

# %%
df.head()
# Out:
#    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0     10452 2022-11-07               Fries   3.49    573.07       Online
# 1     10453 2022-11-07           Beverages   2.95    745.76       Online
# 2     10454 2022-11-07       Sides & Other   4.99    200.40     In-store
# 3     10455 2022-11-08             Burgers  12.99    569.67     In-store
# 4     10456 2022-11-08  Chicken Sandwiches   9.95    201.01     In-store
#
#   Payment Method             Manager    City  TotalSales
# 0      Gift Card    Tom      Jackson  London   2000.0143
# 1      Gift Card         Pablo Perez  Madrid   2199.9920
# 2      Gift Card       Joao    Silva  Lisbon    999.9960
# 3    Credit Card       Walter Muller  Berlin   7400.0133
# 4    Credit Card       Walter Muller  Berlin   2000.0495

# %%
df['Month'] = df['Date'].dt.month
df
# Out:
#      Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0       10452 2022-11-07               Fries   3.49    573.07       Online
# 1       10453 2022-11-07           Beverages   2.95    745.76       Online
# 2       10454 2022-11-07       Sides & Other   4.99    200.40     In-store
# 3       10455 2022-11-08             Burgers  12.99    569.67     In-store
# 4       10456 2022-11-08  Chicken Sandwiches   9.95    201.01     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 249     10709 2022-12-28       Sides & Other   4.99    200.40   Drive-thru
# 250     10710 2022-12-29             Burgers  12.99    754.43   Drive-thru
# 251     10711 2022-12-29  Chicken Sandwiches   9.95    281.41   Drive-thru
# 252     10712 2022-12-29               Fries   3.49    630.37   Drive-thru
# 253     10713 2022-12-29           Beverages   2.95    677.97   Drive-thru
#
#     Payment Method             Manager    City  TotalSales  Month
# ...

# %%
df[(df.Month == 11)].TotalSales.mean()
# Out:
# np.float64(2939.0677734513274)

# %%
df[(df.Month == 12)].TotalSales.mean()
# Out:
# np.float64(3102.1361758865246)

# %%
df.Month.dtype
# Out:
# dtype('int64')

# %%
df.head()
# Out:
#    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0     10452 2022-11-07               Fries   3.49    573.07       Online
# 1     10453 2022-11-07           Beverages   2.95    745.76       Online
# 2     10454 2022-11-07       Sides & Other   4.99    200.40     In-store
# 3     10455 2022-11-08             Burgers  12.99    569.67     In-store
# 4     10456 2022-11-08  Chicken Sandwiches   9.95    201.01     In-store
#
#   Payment Method             Manager    City  TotalSales  Month
# 0      Gift Card    Tom      Jackson  London   2000.0143     11
# 1      Gift Card         Pablo Perez  Madrid   2199.9920     11
# 2      Gift Card       Joao    Silva  Lisbon    999.9960     11
# 3    Credit Card       Walter Muller  Berlin   7400.0133     11
# 4    Credit Card       Walter Muller  Berlin   2000.0495     11

# %%
df.Month
# Out:
# 0      11
# 1      11
# 2      11
# 3      11
# 4      11
#        ..
# 249    12
# 250    12
# 251    12
# 252    12
# 253    12
# Name: Month, Length: 254, dtype: int32

# %%
df.Quantity.std()
# Out:
# np.float64(214.88869921528874)

# %%
df.TotalSales.std()
# Out:
# np.float64(2420.11837804107)

# %%
df.Quantity.var()
# Out:
# np.float64(46177.153050438836)

# %%
df.TotalSales.var()
# Out:
# np.float64(5856972.963732139)

# %%
df.head()
# Out:
#    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 0     10452 2022-11-07               Fries   3.49    573.07       Online
# 1     10453 2022-11-07           Beverages   2.95    745.76       Online
# 2     10454 2022-11-07       Sides & Other   4.99    200.40     In-store
# 3     10455 2022-11-08             Burgers  12.99    569.67     In-store
# 4     10456 2022-11-08  Chicken Sandwiches   9.95    201.01     In-store
#
#   Payment Method             Manager    City  TotalSales  Month
# 0      Gift Card    Tom      Jackson  London   2000.0143     11
# 1      Gift Card         Pablo Perez  Madrid   2199.9920     11
# 2      Gift Card       Joao    Silva  Lisbon    999.9960     11
# 3    Credit Card       Walter Muller  Berlin   7400.0133     11
# 4    Credit Card       Walter Muller  Berlin   2000.0495     11

# %%
df.groupby('Product')[['Quantity', 'TotalSales']].agg({'Quantity' : 'mean','TotalSales':'mean'})
# Out:
#                       Quantity   TotalSales
# Product
# Beverages           699.662800  2064.005260
# Burgers             558.121346  7249.996287
# Chicken Sandwiches  214.152308  2204.647981
# Fries               628.124314  2464.201771
# Sides & Other       200.400000   999.996000

# %%
df.groupby('Product')[['Quantity', 'TotalSales']].agg({
    'Quantity': 'mean',
    'TotalSales': 'mean'
})
# Out:
#                       Quantity   TotalSales
# Product
# Beverages           699.662800  2064.005260
# Burgers             558.121346  7249.996287
# Chicken Sandwiches  214.152308  2204.647981
# Fries               628.124314  2464.201771
# Sides & Other       200.400000   999.996000

# %%
round(df.groupby('Product').agg(
    Quantity=('Quantity', 'mean'),
    TotalSales=('TotalSales', 'mean')
),1)
# Out:
#                     Quantity  TotalSales
# Product
# Beverages              699.7      2064.0
# Burgers                558.1      7250.0
# Chicken Sandwiches     214.2      2204.6
# Fries                  628.1      2464.2
# Sides & Other          200.4      1000.0
